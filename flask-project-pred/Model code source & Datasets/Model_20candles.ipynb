# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from tqdm import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, TimeDistributed, LSTM, Dense, Dropout, GlobalAveragePooling2D,
    BatchNormalization, Bidirectional
)
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# ====== CONFIG ======
SEQ_LEN = 5
IMG_SIZE = (224, 224)
BATCH_SIZE = 16
EPOCHS = 30
NUM_CLASSES = 2
DATASET_DIR = 'train_test_20'
MODEL_DIR = 'models'
os.makedirs(MODEL_DIR, exist_ok=True)
MODEL_SAVE_PATH = os.path.join(MODEL_DIR, f'20bougie_3stride_model_{datetime.now().strftime("%Y%m%d_%H%M%S")}.keras')

# ====== DATA AUGMENTATION FUNCTION ======
def augment_image(image):
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.random_brightness(image, max_delta=0.2)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    image = tf.image.random_saturation(image, 0.8, 1.2)
    image = tf.clip_by_value(image, 0, 255)
    return image

# ====== DATA LOADING ======
def load_sequences(data_dir, augment=False):
    X, y = [], []
    class_map = {'uptrend': 0, 'downtrend': 1}
    for label in class_map:
        class_path = os.path.join(data_dir, label)
        for seq_folder in tqdm(os.listdir(class_path), desc=f"Loading {label}"):
            folder_path = os.path.join(class_path, seq_folder)
            sequence = []
            valid = True
            for i in range(SEQ_LEN):
                img_path = os.path.join(folder_path, f'img_{i}.png')
                if not os.path.exists(img_path):
                    valid = False
                    break
                img = load_img(img_path, target_size=IMG_SIZE)
                img = img_to_array(img)

                if augment:
                    img = augment_image(img)

                img = preprocess_input(img)
                sequence.append(img)
            if valid:
                X.append(sequence)
                y.append(class_map[label])
    return np.array(X), np.array(y)

print("[INFO] Loading data...")
X, y = load_sequences(DATASET_DIR, augment=False)
y_cat = to_categorical(y, num_classes=NUM_CLASSES)
X_train, X_test, y_train, y_test = train_test_split(X, y_cat, test_size=0.2, stratify=y_cat, random_state=42)

# Reload training set with augmentation and correct labels
X_aug, y_aug = load_sequences(DATASET_DIR, augment=True)
y_aug_cat = to_categorical(y_aug, num_classes=NUM_CLASSES)

# Utilise X_aug et y_aug_cat comme ensemble d'entraînement
X_train, y_train = X_aug, y_aug_cat


# ====== CLASS WEIGHTS ======
y_train_labels = np.argmax(y_train, axis=1)
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train_labels), y=y_train_labels)
class_weights = dict(enumerate(class_weights))

# ====== MODEL DEFINITION ======
print("[INFO] Building end-to-end model...")
def build_model():
    input_shape = (SEQ_LEN, *IMG_SIZE, 3)
    inputs = Input(shape=input_shape)

    base_cnn = ResNet50(include_top=False, weights='imagenet', input_shape=(*IMG_SIZE, 3))
    for layer in base_cnn.layers[:-10]:
        layer.trainable = False

    cnn = TimeDistributed(base_cnn)(inputs)
    pooled = TimeDistributed(GlobalAveragePooling2D())(cnn)
    norm = BatchNormalization()(pooled)

    x = Bidirectional(LSTM(128, return_sequences=False))(norm)
    x = Dropout(0.5)(x)
    x = Dense(64, activation='relu', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(0.3)(x)
    outputs = Dense(NUM_CLASSES, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

model = build_model()
model.compile(
    optimizer=Adam(1e-4),
    loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

# ====== CALLBACKS ======
callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1),
    ModelCheckpoint(MODEL_SAVE_PATH, save_best_only=True, monitor='val_accuracy', verbose=1)
]

# ====== TRAIN ======
print("[INFO] Training model...")
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    class_weight=class_weights,
    callbacks=callbacks,
    verbose=2
)

# ====== EVALUATE ======
y_pred_probs = model.predict(X_test)
y_true = np.argmax(y_test, axis=1)
y_pred = np.argmax(y_pred_probs, axis=1)

print("[INFO] Classification Report:")
print(classification_report(y_true, y_pred, target_names=['Uptrend', 'Downtrend']))

# ====== CONFUSION MATRIX ======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=["Uptrend", "Downtrend"], yticklabels=["Uptrend", "Downtrend"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# ====== LEARNING CURVES ======
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss Over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy Over Epochs')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [INFO] Loading data...
# Loading uptrend: 100%|██████████| 586/586 [03:58<00:00,  2.45it/s]
# Loading downtrend: 100%|██████████| 531/531 [07:10<00:00,  1.23it/s]
# Loading uptrend: 100%|██████████| 586/586 [03:39<00:00,  2.67it/s]
# Loading downtrend: 100%|██████████| 531/531 [02:38<00:00,  3.35it/s]
# [INFO] Building end-to-end model...
# [INFO] Training model...
# Epoch 1/30
#
# Epoch 1: val_accuracy improved from -inf to 0.53125, saving model to models\20bougie_3stride_model_20250531_034748.keras
# 70/70 - 1381s - 20s/step - accuracy: 0.5318 - loss: 0.7479 - val_accuracy: 0.5312 - val_loss: 0.7105 - learning_rate: 1.0000e-04
# Epoch 2/30
#
# Epoch 2: val_accuracy improved from 0.53125 to 0.56696, saving model to models\20bougie_3stride_model_20250531_034748.keras
# 70/70 - 1047s - 15s/step - accuracy: 0.6902 - loss: 0.6223 - val_accuracy: 0.5670 - val_loss: 0.6934 - learning_rate: 1.0000e-04
# Epoch 3/30
#
# Epoch 3: val_accuracy improved from 0.56696 to 0.66964, saving model to models\20bougie_3stride_model_20250531_034748.keras
# 70/70 - 1162s - 17s/step - accuracy: 0.7475 - loss: 0.5763 - val_accuracy: 0.6696 - val_loss: 0.6407 - learning_rate: 1.0000e-04
# Epoch 4/30
#
# Epoch 4: val_accuracy did not improve from 0.66964
# 70/70 - 1094s - 16s/step - accuracy: 0.7932 - loss: 0.5124 - val_accuracy: 0.6652 - val_loss: 0.6307 - learning_rate: 1.0000e-04
# Epoch 5/30
#
# Epoch 5: val_accuracy improved from 0.66964 to 0.68304, saving model to models\20bougie_3stride_model_20250531_034748.keras
# 70/70 - 1063s - 15s/step - accuracy: 0.8630 - loss: 0.4512 - val_accuracy: 0.6830 - val_loss: 0.6104 - learning_rate: 1.0000e-04
# Epoch 6/30
#
# Epoch 6: val_accuracy improved from 0.68304 to 0.68750, saving model to models\20bougie_3stride_model_20250531_034748.keras
# 70/70 - 1054s - 15s/step - accuracy: 0.8997 - loss: 0.4058 - val_accuracy: 0.6875 - val_loss: 0.6105 - learning_rate: 1.0000e-04
# Epoch 7/30
#
# Epoch 7: val_accuracy improved from 0.68750 to 0.75893, saving model to models\20bougie_3stride_model_20250531_034748.keras
# 70/70 - 1004s - 14s/step - accuracy: 0.9436 - loss: 0.3484 - val_accuracy: 0.7589 - val_loss: 0.5832 - learning_rate: 1.0000e-04
# Epoch 8/30
#
# Epoch 8: val_accuracy improved from 0.75893 to 0.76339, saving model to models\20bougie_3stride_model_20250531_034748.keras
# 70/70 - 737s - 11s/step - accuracy: 0.9633 - loss: 0.3149 - val_accuracy: 0.7634 - val_loss: 0.5484 - learning_rate: 1.0000e-04
# Epoch 9/30
#
# Epoch 9: val_accuracy did not improve from 0.76339
# 70/70 - 735s - 11s/step - accuracy: 0.9776 - loss: 0.2898 - val_accuracy: 0.7188 - val_loss: 0.6418 - learning_rate: 1.0000e-04
# Epoch 10/30
#
# Epoch 10: val_accuracy did not improve from 0.76339
# 70/70 - 747s - 11s/step - accuracy: 0.9821 - loss: 0.2735 - val_accuracy: 0.7411 - val_loss: 0.6068 - learning_rate: 1.0000e-04
# Epoch 11/30
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 11: val_accuracy did not improve from 0.76339
# 70/70 - 693s - 10s/step - accuracy: 0.9848 - loss: 0.2642 - val_accuracy: 0.7009 - val_loss: 0.6368 - learning_rate: 1.0000e-04
# Epoch 12/30
#
# Epoch 12: val_accuracy improved from 0.76339 to 0.79464, saving model to models\20bougie_3stride_model_20250531_034748.keras
# 70/70 - 715s - 10s/step - accuracy: 0.9946 - loss: 0.2531 - val_accuracy: 0.7946 - val_loss: 0.5461 - learning_rate: 5.0000e-05
# Epoch 13/30
#
# Epoch 13: val_accuracy did not improve from 0.79464
# 70/70 - 661s - 9s/step - accuracy: 0.9928 - loss: 0.2524 - val_accuracy: 0.7455 - val_loss: 0.5915 - learning_rate: 5.0000e-05
# Epoch 14/30
#
# Epoch 14: val_accuracy did not improve from 0.79464
# 70/70 - 666s - 10s/step - accuracy: 0.9991 - loss: 0.2466 - val_accuracy: 0.7634 - val_loss: 0.5328 - learning_rate: 5.0000e-05
# Epoch 15/30
#
# Epoch 15: val_accuracy did not improve from 0.79464
# 70/70 - 692s - 10s/step - accuracy: 0.9973 - loss: 0.2473 - val_accuracy: 0.7411 - val_loss: 0.5695 - learning_rate: 5.0000e-05
# Epoch 16/30
#
# Epoch 16: val_accuracy did not improve from 0.79464
# 70/70 - 665s - 10s/step - accuracy: 0.9964 - loss: 0.2438 - val_accuracy: 0.7768 - val_loss: 0.5487 - learning_rate: 5.0000e-05
# Epoch 17/30
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 17: val_accuracy did not improve from 0.79464
# 70/70 - 694s - 10s/step - accuracy: 0.9964 - loss: 0.2428 - val_accuracy: 0.7679 - val_loss: 0.5512 - learning_rate: 5.0000e-05
# Epoch 18/30
#
# Epoch 18: val_accuracy did not improve from 0.79464
# 70/70 - 781s - 11s/step - accuracy: 0.9991 - loss: 0.2397 - val_accuracy: 0.7812 - val_loss: 0.5305 - learning_rate: 2.5000e-05
# Epoch 19/30
#
# Epoch 19: val_accuracy did not improve from 0.79464
# 70/70 - 733s - 10s/step - accuracy: 0.9991 - loss: 0.2414 - val_accuracy: 0.7812 - val_loss: 0.5257 - learning_rate: 2.5000e-05
# Epoch 20/30
#
# Epoch 20: val_accuracy did not improve from 0.79464
# 70/70 - 704s - 10s/step - accuracy: 0.9991 - loss: 0.2364 - val_accuracy: 0.7723 - val_loss: 0.5463 - learning_rate: 2.5000e-05
# Epoch 21/30
#
# Epoch 21: val_accuracy did not improve from 0.79464
# 70/70 - 743s - 11s/step - accuracy: 0.9982 - loss: 0.2385 - val_accuracy: 0.7768 - val_loss: 0.5283 - learning_rate: 2.5000e-05
# Epoch 22/30
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
#
# Epoch 22: val_accuracy did not improve from 0.79464
# 70/70 - 695s - 10s/step - accuracy: 1.0000 - loss: 0.2373 - val_accuracy: 0.7679 - val_loss: 0.5622 - learning_rate: 2.5000e-05
# Epoch 23/30
#
# Epoch 23: val_accuracy did not improve from 0.79464
# 70/70 - 740s - 11s/step - accuracy: 0.9991 - loss: 0.2394 - val_accuracy: 0.7902 - val_loss: 0.5323 - learning_rate: 1.2500e-05
# Epoch 24/30
#
# Epoch 24: val_accuracy improved from 0.79464 to 0.80357, saving model to models\20bougie_3stride_model_20250531_034748.keras
# 70/70 - 749s - 11s/step - accuracy: 0.9973 - loss: 0.2391 - val_accuracy: 0.8036 - val_loss: 0.5353 - learning_rate: 1.2500e-05
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 19.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 135s 15s/step
# [INFO] Classification Report:
#               precision    recall  f1-score   support
#
#      Uptrend       0.84      0.72      0.78       118
#    Downtrend       0.73      0.85      0.79       106
#
#     accuracy                           0.78       224
#    macro avg       0.79      0.78      0.78       224
# weighted avg       0.79      0.78      0.78       224

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.resnet import preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical

# ====== CONFIG ======
SEQ_LEN = 5
IMG_SIZE = (224, 224)
NUM_CLASSES = 2
CLASS_NAMES = ['Uptrend', 'Downtrend']

EXTERNAL_DATA_DIR = 'backtest_20'  # <-- Remplace par le chemin de ton dossier externe
MODEL_PATH = 'models\end2end_model_20250530_203710.keras'  # <-- Ton modèle entraîné

# ====== Fonction pour charger les séquences ======
def load_sequences(data_dir):
    X, y = [], []
    class_map = {'uptrend': 0, 'downtrend': 1}
    for label in class_map:
        class_path = os.path.join(data_dir, label)
        if not os.path.exists(class_path):
            continue
        for seq_folder in tqdm(os.listdir(class_path), desc=f"Loading {label}"):
            folder_path = os.path.join(class_path, seq_folder)
            sequence = []
            valid = True
            for i in range(SEQ_LEN):
                img_path = os.path.join(folder_path, f'img_{i}.png')
                if not os.path.exists(img_path):
                    valid = False
                    break
                img = load_img(img_path, target_size=IMG_SIZE)
                img = img_to_array(img)
                img = preprocess_input(img)
                sequence.append(img)
            if valid:
                X.append(sequence)
                y.append(class_map[label])
    return np.array(X), np.array(y)

# ====== Charger les données externes ======
print("[INFO] Chargement des données externes...")
X_ext, y_ext = load_sequences(EXTERNAL_DATA_DIR)
y_ext_cat = to_categorical(y_ext, num_classes=NUM_CLASSES)

# ====== Charger le modèle ======
print(f"[INFO] Chargement du modèle depuis {MODEL_PATH}...")
model = load_model(MODEL_PATH)

# ====== Prédictions ======
print("[INFO] Prédiction en cours...")
y_pred_probs = model.predict(X_ext)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_ext_cat, axis=1)

# ====== Rapport de classification ======
print("[INFO] Rapport de classification :")
print(classification_report(y_true, y_pred, target_names=CLASS_NAMES))

# ====== Matrice de confusion ======
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
plt.title("Confusion Matrix - External Evaluation")
plt.xlabel("Prédiction")
plt.ylabel("Vérité terrain")
plt.tight_layout()
plt.show()
# Out:
# [INFO] Chargement des données externes...
# Loading uptrend:   0%|          | 0/62 [00:00<?, ?it/s]
# Loading uptrend: 100%|██████████| 62/62 [00:01<00:00, 60.68it/s]
# Loading downtrend: 100%|██████████| 62/62 [00:01<00:00, 61.63it/s]
# [INFO] Chargement du modèle depuis models\end2end_model_20250530_203710.keras...
# [INFO] Prédiction en cours...
# WARNING:tensorflow:6 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000200F2CBA520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 40s 9s/step
# [INFO] Rapport de classification :
#               precision    recall  f1-score   support
#
#      Uptrend       0.65      0.58      0.62        62
#    Downtrend       0.62      0.69      0.66        62
#
#     accuracy                           0.64       124
#    macro avg       0.64      0.64      0.64       124
# weighted avg       0.64      0.64      0.64       124
